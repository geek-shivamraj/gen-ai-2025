# %% [markdown]
# #### Ollama
# Ollama supports embedding models, making it possible to build retrieval augmented generation (RAG) applications that combine text prompts with existing documents or other data.
#
# Before using the model, you have to manually download ollama: https://ollama.com/download <br><br>
# Then post ollama download, pull specific model with specific parameters like 1B, 4B etc. you want to use for embedding. Refer below links<br>
#
# https://ollama.com/search<br>
# https://ollama.com/blog/embedding-models<br>
# https://github.com/ollama/ollama<br>

# %%
from langchain_ollama import OllamaEmbeddings

# %%
#gemma:2b
embeddings=(
    OllamaEmbeddings(model="nomic-embed-text")  ##by default it ues llama2
)

# %%
embeddings
# Out:
# OllamaEmbeddings(model='nomic-embed-text', validate_model_on_init=False, base_url=None, client_kwargs={}, async_client_kwargs={}, sync_client_kwargs={}, mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, keep_alive=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None)

# %%
r1=embeddings.embed_documents(
    [
       "Alpha is the first letter of Greek alphabet",
       "Beta is the second letter of Greek alphabet", 
    ]
)

# %%
len(r1[0])
# Out:
# 768

# %%
r1[1]
# Out:
# [0.027968641,
#  0.022309931,
#  -0.14929491,
#  -0.061008636,
#  0.116602205,
#  -0.008279861,
#  -0.023945915,
#  0.00069918885,
#  -0.017208748,
#  -0.03631741,
#  -0.027786754,
#  0.12055564,
#  0.060449433,
#  0.04256054,
#  0.04382928,
#  -0.075374186,
#  0.0052066576,
#  -0.04483706,
#  -0.038596272,
#  0.0031478812,
#  0.010090608,
#  -0.020522717,
#  -0.038323276,
#  -0.03603842,
#  0.104611516,
#  0.091959864,
#  0.03976345,
#  0.032458227,
#  -0.019806283,
#  -0.06337893,
#  -0.022693614,
#  0.0034757806,
#  0.046672728,
#  -0.026597273,
#  0.03261218,
#  0.010166379,
#  -0.017526733,
#  0.035565,
#  0.022071151,
#  -0.009085374,
#  -0.012428071,
#  -0.0158074,
#  -0.0062773586,
#  0.025120977,
#  0.049810287,
#  -0.04889685,
#  -0.010839635,
#  0.08338665,
#  0.071245715,
#  -0.022325197,
#  0.06911708,
#  -0.01666343,
#  0.012909675,
#  0.006708389,
#  0.0010550574,
#  -0.002379246,
#  0.049441136,
#  -0.038067713,
#  0.009986478,
#  -0.012171069,
#  0.05656025,
# ...

# %%
embeddings.embed_query("What is the second letter of Greek alphabet ")
# Out:
# [0.020760937,
#  0.0006997684,
#  -0.12901461,
#  -0.07128859,
#  0.079796575,
#  -0.035242755,
#  -0.048196286,
#  0.0003045658,
#  -0.016064182,
#  -0.013962772,
#  -0.053675923,
#  0.12309978,
#  0.059645023,
#  0.010432971,
#  0.031509314,
#  -0.054526597,
#  0.027313536,
#  -0.033905674,
#  -0.050513804,
#  0.0042014914,
#  -0.037512235,
#  -0.021368323,
#  -0.013355977,
#  -0.025988296,
#  0.099144004,
#  0.07229169,
#  0.087398395,
#  0.037745707,
#  -0.025376521,
#  -0.053594787,
#  -0.04218524,
#  -0.015017551,
#  0.049888276,
#  -0.06663378,
#  0.011506645,
#  0.015098782,
#  -0.0154380575,
#  0.049255416,
#  0.0076397536,
#  -0.0076405904,
#  -0.023765491,
#  -0.05353669,
#  -0.005844128,
#  0.023598718,
#  0.047551315,
#  -0.07078288,
#  -0.060907915,
#  0.071147606,
#  0.022933302,
#  -0.059689585,
#  0.04743871,
#  -0.00021793153,
#  -0.007151604,
#  0.014609836,
#  -0.023302367,
#  0.009368202,
#  0.029365325,
#  -0.024033472,
#  0.043791257,
#  0.0087463325,
# ...

# %%
### Other Embedding Models
### https://ollama.com/blog/embedding-models
embeddings = OllamaEmbeddings(model="mxbai-embed-large")
text = "This is a test document."
query_result = embeddings.embed_query(text)
query_result
# Out:
# [0.0071113566,
#  -0.018591946,
#  0.0557587,
#  0.024306772,
#  -0.051248275,
#  -0.0021817128,
#  -0.0024550227,
#  -0.008715661,
#  0.022060346,
#  0.05522692,
#  0.013424087,
#  0.026520604,
#  0.026836716,
#  0.0071707726,
#  -0.02077827,
#  0.012974587,
#  -0.022501286,
#  0.031175273,
#  -0.03088915,
#  -0.02851999,
#  -0.042156905,
#  0.014374696,
#  -0.053481393,
#  -0.019485662,
#  -0.025101392,
#  0.03527785,
#  -0.012687309,
#  0.004283673,
#  0.06716106,
#  0.01887754,
#  -0.0041333404,
#  0.015787853,
#  -0.035964534,
#  -0.047136325,
#  0.020435588,
#  -0.043361347,
#  0.062310327,
#  -0.035110995,
#  0.0022417319,
#  -0.03196678,
#  0.0045348196,
#  0.009774775,
#  0.04286569,
#  -0.03425406,
#  -0.08438373,
#  -0.04422639,
#  -0.014794692,
#  -0.008098996,
#  -0.027715873,
#  -0.027541496,
#  0.01483522,
#  0.030843657,
#  -0.010892088,
#  -0.03555579,
#  0.0006096453,
#  -0.02056147,
#  -0.024287581,
#  -0.024677262,
#  -0.03626839,
#  0.06537211,
#  0.052435264,
# ...

# %%
len(query_result)
# Out:
# 1024
